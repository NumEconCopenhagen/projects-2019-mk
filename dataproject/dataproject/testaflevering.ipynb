# %%
import functions as fc
from statsmodels.formula.api import ols

# %%
IBM_data = fc.prices("IBM")
IBM_S = fc.searches("IBM")
IBM = fc.combine_data_frames(IBM_S, IBM_data)
IBM.columns=["searches", "open", "high", "low", "close", "volume"]
IBM.head()
# Out:
#             searches      open      high       low     close     volume
# date
# 2018-01-01        29       NaN       NaN       NaN       NaN        NaN
# 2018-01-02        59  146.1117  146.4049  145.2038  145.8753  4202503.0
# 2018-01-03        68  148.7975  151.1334  147.8423  149.8851  9441567.0
# 2018-01-04        72  150.9821  153.5106  150.7173  152.9208  7556249.0
# 2018-01-05        67  153.6206  154.0556  152.3543  153.6679  5195764.0

# %%
fc.deletenan(IBM).head()
# Out:
#             searches      open      high       low     close     volume
# date
# 2018-01-02        59  146.1117  146.4049  145.2038  145.8753  4202503.0
# 2018-01-03        68  148.7975  151.1334  147.8423  149.8851  9441567.0
# 2018-01-04        72  150.9821  153.5106  150.7173  152.9208  7556249.0
# 2018-01-05        67  153.6206  154.0556  152.3543  153.6679  5195764.0
# 2018-01-08        68  153.8287  155.0061  152.9217  154.5947  5237523.0

# %%
fc.scatterplot(IBM)

# %%
fc.OLS(IBM)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  close   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     3.304
# Date:                Tue, 02 Apr 2019   Prob (F-statistic):             0.0742
# Time:                        16:49:14   Log-Likelihood:                -176.08
# No. Observations:                  61   AIC:                             356.2
# Df Residuals:                      59   BIC:                             360.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    138.4065      6.675     20.736      0.000     125.050     151.763
# ...

# %%
fc.scatterols(IBM)

# %%
def scatterplot(firm):
    firm_nonan = firm.dropna()
    return firm_nonan.plot.scatter(x = "searches", y = "close")

# %%
scatterplot(IBM)

# %%
fc.fig(IBM)

# %%
fc.bondfig(SPX_weekly, US_bond_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d847de429af7> in <module>
# ----> 1 fc.bondfig(SPX_weekly, US_bond_clean)
#
# NameError: name 'SPX_weekly' is not defined
