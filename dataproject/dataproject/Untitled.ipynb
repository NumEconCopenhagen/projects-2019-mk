# %%
# %load_ext autoreload
# %autoreload 2

import functions as fc
from datetime import datetime

# %%
start = datetime(2019,1,1)
end = datetime(2019,3,31)
ticker = 'GOOG'

df = fc.prices(ticker, start, end)

# %%
df_searches = fc.searches('GOOG')

# %%
df_searches.head(50)
# Out:
#             GOOG
# date
# 2014-04-06   100
# 2014-04-13    98
# 2014-04-20    99
# 2014-04-27    98
# 2014-05-04    97
# 2014-05-11    97
# 2014-05-18    99
# 2014-05-25    96
# 2014-06-01    94
# 2014-06-08    91
# 2014-06-15    92
# 2014-06-22    87
# 2014-06-29    85
# 2014-07-06    86
# 2014-07-13    86
# 2014-07-20    86
# 2014-07-27    84
# 2014-08-03    84
# 2014-08-10    86
# 2014-08-17    79
# 2014-08-24    73
# 2014-08-31    74
# 2014-09-07    75
# 2014-09-14    73
# 2014-09-21    74
# 2014-09-28    71
# 2014-10-05    72
# 2014-10-12    75
# 2014-10-19    72
# 2014-10-26    71
# 2014-11-02    72
# 2014-11-09    70
# 2014-11-16    73
# 2014-11-23    68
# 2014-11-30    72
# 2014-12-07    74
# 2014-12-14    72
# 2014-12-21    71
# 2014-12-28    69
# 2015-01-04    70
# 2015-01-11    71
# 2015-01-18    72
# 2015-01-25    72
# 2015-02-01    68
# 2015-02-08    69
# 2015-02-15    68
# 2015-02-22    70
# 2015-03-01    72
# 2015-03-08    69
# 2015-03-15    69

# %%
fc.combine_data_frames(df,df_searches)
# Out:
#                open     high      low    close     volume   GOOG
# date
# 2014-04-06      NaN      NaN      NaN      NaN        NaN  100.0
# 2014-04-13      NaN      NaN      NaN      NaN        NaN   98.0
# 2014-04-20      NaN      NaN      NaN      NaN        NaN   99.0
# 2014-04-27      NaN      NaN      NaN      NaN        NaN   98.0
# 2014-05-04      NaN      NaN      NaN      NaN        NaN   97.0
# 2014-05-11      NaN      NaN      NaN      NaN        NaN   97.0
# 2014-05-18      NaN      NaN      NaN      NaN        NaN   99.0
# 2014-05-25      NaN      NaN      NaN      NaN        NaN   96.0
# 2014-06-01      NaN      NaN      NaN      NaN        NaN   94.0
# 2014-06-08      NaN      NaN      NaN      NaN        NaN   91.0
# 2014-06-15      NaN      NaN      NaN      NaN        NaN   92.0
# 2014-06-22      NaN      NaN      NaN      NaN        NaN   87.0
# 2014-06-29      NaN      NaN      NaN      NaN        NaN   85.0
# ...
